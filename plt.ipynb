# %%
import matplotlib.pyplot as plt

# %%
X=[1,2,3,4]
y=[1200,1500,3000,1800]

# %%
plt.plot(x,y ,color="green",linestyle="-",linewidth=2,marker="o")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.plot(x,y ,color="green",linestyle="-",linewidth=2,marker="o")
#
# NameError: name 'x' is not defined

# %%
x=[1,2,3,4]

# %%
plt.plot(x,y ,color="green",linestyle="-",linewidth=2,marker="o")

# %%
plt.xlabel("months")
# Out:
# Text(0.5, 0, 'months')

# %%
plt.ylabel("sales per month")
# Out:
# Text(0, 0.5, 'sales per month')

# %%
plt.title("monthly sales data report")
# Out:
# Text(0.5, 1.0, 'monthly sales data report')

# %%
plt.legend()
# Out:
# C:\Users\chreh\AppData\Local\Temp\ipykernel_11948\4061938096.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.legend(loc="upper right")
# Out:
# C:\Users\chreh\AppData\Local\Temp\ipykernel_11948\1678256137.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper right")

# %%
plt.grid(color="gray",linestyle=":",linewidth=1)

# %%
plt.xlim(1,4)
# Out:
# (1.0, 4.0)

# %%
plt.ylim(0,3000)
# Out:
# (0.0, 3000.0)

# %%
plt.xticks([1,2,3,4],["m1","m2","m3","m4"])
# Out:
# ([<matplotlib.axis.XTick at 0x1aca0fc39d0>,
# ...
#  [Text(1, 0, 'm1'), Text(2, 0, 'm2'), Text(3, 0, 'm3'), Text(4, 0, 'm4')])

# %%
plt.show()

# %%
x=["Monday","Tuesday","Wednesday","Thrusday","Friday","Saturday"]

# %%
y=[1000,1500,1800,2000,3000,2500,3500,4000]

# %%
plt.plot(x,y ,color='green',linestyle='-',linewidth=2,marker='o',label='line1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plt.plot(x,y ,color='green',linestyle='-',linewidth=2,marker='o',label='line1')
#
# File c:\Users\chreh\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# ...

# %%
plt.plot(x,y,color="purple",marker="o",linestyle="dotted",linewidth=10,label="line1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.plot(x,y,color="purple",marker="o",linestyle="dotted",linewidth=10,label="line1")
#
# File c:\Users\chreh\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# ...

# %%
x=["Monday","Tuesday","Wednesday","Thrusday","Friday","Saturday"]

# %%
y=[1000,1500,1800,2000,3000,2500,3500,4000]

# %%
plt.plot(x,y ,color="green",linestyle="-",linewidth=2,marker="o")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 plt.plot(x,y ,color="green",linestyle="-",linewidth=2,marker="o")
#
# File c:\Users\chreh\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File c:\Users\chreh\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt

# %%
regions = ["South", "West", "North", "East"]

# %%
revenues = [2900, 8000, 700, 7888]

# %%
plt.pie(revenues, labels=regions, autopct="%1.1F",colors=["purple","green","white","yellow"])
plt.title("Contribution by reigons")
# Out:
# Text(0.5, 1.0, 'Contribution by reigons')

# %%
x=["Mon","Tue","Wed","Thru","Fri","Sat","Sun"]

# %%
y =['500','600','700','1000','1200','1500','2000']

# %%
plt.plot(x,y)

# %%
plt.hist(data = x,x = y)
# Out:
# (array([1., 1., 0., 1., 0., 1., 1., 0., 1., 1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.grid(color='purple',linestyle='--',linewidth=0.5)

# %%
hours_studies = [1,2,3,4,5,6,7,8]

# %%
exam_scores = []
